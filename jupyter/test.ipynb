# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## a==b 返回bool类型数组
#  import numpy as np
#  a = np.array([1,2,3,4,5,6])
#  b = np.array([0,0,3,4,5,6])
#  a==b
#  array([False, False,  True,  True,  True,  True])

# %%
import numpy as np

a = np.array([1,2,3,4,5,6])
b = np.array([0,0,3,4,5,6])
c = np.array(a==b,dtype=np.int8)
d = np.array(a==b)
print(c)
print(d)
# Out:
# [0 0 1 1 1 1]
# [False False  True  True  True  True]

# %% [markdown]
# ##  交叉熵误差

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,1,0.01)
y = -np.log(x)
plt.plot(x,y)
plt.show()
# Out:
# C:\Users\funti\AppData\Local\Temp\ipykernel_26296\3703055131.py:5: RuntimeWarning: divide by zero encountered in log
#   y = -np.log(x)
