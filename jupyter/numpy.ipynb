# %% [markdown]
# ## numpy笔记 重要函数

# %%
import numpy as np
import torch

y = np.array([1,2,3,4,5,6])
print(y)
print(f"y shape :{y.shape}")
x = y.reshape(1,y.size)
print(f"y reshape shape :{x.shape}")
print(f"y reshape :{y.reshape(1,y.size)}")
print(y.size)
# Out:
# [1 2 3 4 5 6]
# y shape :(6,)
# y reshape shape :(1, 6)
# y reshape :[[1 2 3 4 5 6]]
# 6
