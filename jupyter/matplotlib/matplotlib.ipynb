# %% [markdown]
# # Matplotlib 函数介绍

# %% [markdown]
# ### 二维空间散点图

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure();
axe = plt.axes()

x = np.arange(-10,10,1)
y = np.arange(-10,10,1)

X,Y = np.meshgrid(x,y)

plt.plot(X,Y,'o--')
plt.show()
